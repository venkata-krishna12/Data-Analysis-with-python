# %%
import pandas as pd
df=pd.read_csv('/content/dermatology_database_1.csv')
df
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0           2        2                 0        3                   0
# 1           3        3                 3        2                   1
# 2           2        1                 2        3                   1
# 3           2        2                 2        0                   0
# 4           2        3                 2        2                   2
# ..        ...      ...               ...      ...                 ...
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 35 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   erythema                             366 non-null    int64
#  1   scaling                              366 non-null    int64
#  2   definite_borders                     366 non-null    int64
#  3   itching                              366 non-null    int64
#  4   koebner_phenomenon                   366 non-null    int64
#  5   polygonal_papules                    366 non-null    int64
#  6   follicular_papules                   366 non-null    int64
#  7   oral_mucosal_involvement             366 non-null    int64
#  8   knee_and_elbow_involvement           366 non-null    int64
#  9   scalp_involvement                    366 non-null    int64
#  10  family_history                       366 non-null    int64
# ...

# %%
df.describe()
# Out:
#          erythema     scaling  definite_borders     itching  \
# count  366.000000  366.000000        366.000000  366.000000
# mean     2.068306    1.795082          1.549180    1.366120
# std      0.664753    0.701527          0.907525    1.138299
# min      0.000000    0.000000          0.000000    0.000000
# 25%      2.000000    1.000000          1.000000    0.000000
# 50%      2.000000    2.000000          2.000000    1.000000
# 75%      2.000000    2.000000          2.000000    2.000000
# max      3.000000    3.000000          3.000000    3.000000
#
#        koebner_phenomenon  polygonal_papules  follicular_papules  \
# count          366.000000         366.000000          366.000000
# mean             0.633880           0.448087            0.166667
# std              0.908016           0.957327            0.570588
# min              0.000000           0.000000            0.000000
# 25%              0.000000           0.000000            0.000000
# ...

# %%
for column in df.columns:
    df[column] = pd.to_numeric(df[column], errors='coerce')

# %%
df = df.dropna()
df.shape
# Out:
# (358, 35)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
df_scaler=scaler.fit_transform(df)
df_scaler=pd.DataFrame(df,columns=df.columns)
df
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0           2        2                 0        3                   0
# 1           3        3                 3        2                   1
# 2           2        1                 2        3                   1
# 3           2        2                 2        0                   0
# 4           2        3                 2        2                   2
# ..        ...      ...               ...      ...                 ...
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the size of the plot
plt.figure(figsize=(15, 10))

# Create a boxplot for each feature
sns.boxplot(data=df.drop('class', axis=1), orient="h", palette="Set2")

# Set plot labels and title
plt.title("Boxplot for Each Feature (Excluding 'class')")
plt.xlabel("Feature Values")
plt.ylabel("Features")

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df.iloc[:, :-1].quantile(0.25)
Q3 = df.iloc[:, :-1].quantile(0.75)

# Calculate the IQR
IQR = Q3 - Q1

# Define the outlier condition: values outside 1.5 * IQR
outliers_condition = ((df.iloc[:, :-1] < (Q1 - 1.5 * IQR)) | (df.iloc[:, :-1] > (Q3 + 1.5 * IQR)))

# Check how many outliers are present in each feature
outliers_count = outliers_condition.sum()
print("Outliers count per feature:\n", outliers_count)
# Out:
# Outliers count per feature:
#  erythema                                 4
# scaling                                  0
# definite_borders                         0
# itching                                  0
# koebner_phenomenon                      18
# polygonal_papules                       68
# follicular_papules                      33
# oral_mucosal_involvement                66
# knee_and_elbow_involvement              23
# scalp_involvement                       16
# family_history                          44
# melanin_incontinence                    69
# eosinophils_infiltrate                  42
# PNL_infiltrate                           7
# fibrosis_papillary_dermis               50
# exocytosis                               0
# acanthosis                             149
# hyperkeratosis                           5
# parakeratosis                            0
# clubbing_rete_ridges                     0
# elongation_rete_ridges                   0
# ...

# %%
# Remove the rows that contain outliers
df_clean = df[~outliers_condition.any(axis=1)]

# Check the shape of the cleaned data
print(f"Original Data Shape: {df.shape}")
print(f"Cleaned Data Shape: {df_clean.shape}")
# Out:
# Original Data Shape: (358, 35)
# Cleaned Data Shape: (43, 35)

# %%
from sklearn.model_selection import train_test_split
x=df.drop('class',axis=1)
y=df['class']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
svm_model = SVC(kernel='linear', random_state=42)
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the SVM model
svm_model.fit(x_train, y_train)

# Predict using the SVM model
svm_predictions = svm_model.predict(x_test)

# Train the Random Forest model
rf_model.fit(x_train, y_train)

# Predict using the Random Forest model
rf_predictions = rf_model.predict(x_test)

# Evaluate the models

print(f"SVM Model Accuracy: {accuracy_score(y_test, svm_predictions)}")
print(f"Random Forest Model Accuracy: {accuracy_score(y_test, rf_predictions)}")
print()
print()
print("SVM Model Results:")
print("Classification Report:\n", classification_report(y_test, svm_predictions))

print("\nRandom Forest Model Results:")
print("Classification Report:\n", classification_report(y_test, rf_predictions))
# Out:
# SVM Model Accuracy: 0.9722222222222222
# Random Forest Model Accuracy: 0.9861111111111112
#
#
# SVM Model Results:
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#            2       1.00      0.86      0.92        14
#            3       1.00      1.00      1.00        14
#            4       0.80      1.00      0.89         8
#            5       1.00      1.00      1.00        12
#            6       1.00      1.00      1.00         2
#
#     accuracy                           0.97        72
#    macro avg       0.97      0.98      0.97        72
# weighted avg       0.98      0.97      0.97        72
#
#
# Random Forest Model Results:
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#            2       1.00      0.93      0.96        14
#            3       1.00      1.00      1.00        14
# ...

# %%
import matplotlib.pyplot as plt

# Set up the size of the plot
plt.figure(figsize=(15, 10))

# Iterate through each feature (excluding 'class') and plot histograms
for i, column in enumerate(df.drop('class', axis=1).columns):
    plt.subplot(6, 6, i+1)  # Create a 6x6 grid of subplots
    plt.hist(df[column], bins=20, color='skyblue', edgecolor='black')
    plt.title(column)
    plt.xlabel('Value')
    plt.ylabel('Frequency')

plt.tight_layout()  # Adjust the layout to prevent overlap
plt.show()
